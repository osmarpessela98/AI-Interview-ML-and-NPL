# %%
# !pip install transformers
# !pip install sentence-transformers
# !pip install pandas
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=1ad5f88abe872e1fc42b84f4c9021be69bf5516767c117c85af7980836747877
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.1.99
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import random
from sklearn.metrics.pairwise import cosine_similarity
import torch
import pandas as pd
from sentence_transformers import SentenceTransformer

# %%
file_path =r"AI interview sample dataset.xlsx"

df = pd.read_excel('/content/AI interview sample dataset.xlsx')

terms_dict = pd.Series(df.Definition.values, index=df.Term).to_dict()

# %%
for index, value in terms_dict.items():
    print(f"Term:{index}, Value:{value}")
# Out:
# Term:A/B Testing, Value:A controlled experiment to compare two versions (A and B) of a web page, app, or product to determine which performs better.
# Term:Bar Chart, Value:A chart that represents categorical data with rectangular bars of varying heights.
# Term:Bias-Variance Trade-off, Value:Balancing the trade-off between underfitting (high bias) and overfitting (high variance) in machine learning models.
# Term:Box Plot (Box-and-Whisker), Value:A visual summary of data distribution, showing quartiles, median, and potential outliers.
# Term:Clustering, Value:Grouping data points based on similarity or distance metrics to discover natural groupings in the data.
# Term:Confidence Interval, Value:A range of values within which the true population parameter is likely to fall with a certain level of confidence.
# Term:Confounding Variables, Value:Variables that affect both the independent and dependent variables in a study, potentially leading to erroneous conclusions.
# Term:Correlation, Value:A statistical measure indicating the strength and direction of a linear relationship between two variables.
# Term:Cross-Entropy, Value:A loss function used in classification problems to measure the difference between predicted and actual class probabilities.
# Term:Cross-Tabulation (Contingency Table), Value:A summary table that displays the relationship between two or more categorical variables.
# Term:Cross-Validation, Value:A technique to assess model performance by splitting data into multiple subsets for training and testing.
# Term:Data Analysis, Value:The process of examining, cleaning, transforming, and interpreting data to extract insights.
# Term:Data Anomaly Detection, Value:Identifying and flagging unusual or unexpected patterns or data points in a dataset.
# Term:Data Cleaning, Value:The process of identifying and correcting errors or inconsistencies in a dataset.
# Term:Data Ethics, Value:Considerations and principles related to the responsible and ethical use of data, including privacy and fairness.
# Term:Data Exploration, Value:The initial phase of data analysis, involving visualizations and summary statistics to understand the dataset's characteristics.
# Term:Data Governance, Value:Establishing processes and policies for data quality, privacy, security, and compliance within an organization.
# Term:Data Mining, Value:The process of discovering patterns, trends, or useful information from large datasets.
# Term:Data Normalization, Value:Scaling numerical data to a standard range (e.g., between 0 and 1) to ensure consistency and comparability.
# Term:Data Preprocessing, Value:The initial steps in data analysis, including cleaning, transforming, and structuring data for analysis.
# Term:Data Sampling, Value:Selecting a subset of data points from a larger dataset to work with, often used for exploratory analysis.
# Term:Data Transformation, Value:Modifying data by scaling, encoding, or creating new features to make it suitable for analysis.
# Term:Data Visualization, Value:Representing data graphically to provide insights and patterns through charts and graphs.
# Term:Data Visualization Libraries, Value:Tools like Matplotlib, Seaborn, and Plotly for creating visual representations of data in Python.
# Term:Data Wrangling, Value:The process of cleaning, reshaping, and preparing data for analysis, often involving merging, pivoting, and aggregating.
# Term:Descriptive Statistics, Value:Statistical methods used to summarize and describe the main features of a dataset.
# Term:Exploratory Data Analysis, Value:The initial investigation of data to understand its main characteristics and patterns.
# Term:Feature Engineering, Value:Creating new informative features from existing ones or external data to improve model performance.
# Term:Feature Selection, Value:The process of choosing relevant input variables (features) for a machine learning model.
# Term:Histogram, Value:A graphical representation of the distribution of numerical data through bins or intervals.
# Term:Hypothesis Testing, Value:A statistical method to determine if an observed effect is statistically significant.
# Term:Inferential Statistics, Value:Techniques for making predictions or inferences about a population based on sample data.
# Term:Machine Learning, Value:A subset of artificial intelligence where models learn patterns and make predictions from data.
# Term:Mean, Value:The average value of a dataset, calculated by summing all values and dividing by the count.
# Term:Median, Value:The middle value in a dataset when sorted, separating the higher and lower halves.
# Term:Missing Data Imputation, Value:The process of filling in missing values in a dataset using techniques like mean, median, or machine learning methods.
# Term:Non-parametric Tests, Value:Statistical tests that do not rely on assumptions about the data's underlying distribution. Examples include the Wilcoxon rank-sum test.
# Term:Normal Distribution, Value:A symmetric probability distribution characterized by its mean and standard deviation.
# Term:Null Hypothesis, Value:A statement that there is no significant effect or relationship in a statistical analysis.
# Term:Outlier, Value:An extreme or unusual data point that deviates significantly from the rest of the data.
# Term:Overfitting, Value:Occurs when a machine learning model learns the training data too well but performs poorly on unseen data.
# Term:P-value, Value:The probability of observing a result as extreme as the one obtained, assuming the null hypothesis is true.
# Term:Principal Component Analysis (PCA), Value:A dimensionality reduction technique to reduce the number of features while preserving important information.
# Term:Regression Analysis, Value:A statistical technique to model the relationship between a dependent and independent variable.
# Term:Resampling Methods, Value:Techniques like bootstrapping and cross-validation used to estimate model performance and mitigate overfitting.
# Term:ROC Curve (Receiver Operating Characteristic), Value:A graphical tool used to assess the performance of binary classification models across different thresholds.
# Term:Scatter Plot, Value:A graphical representation of data points on a two-dimensional plane to explore relationships.
# Term:Standard Deviation, Value:A measure of the dispersion or variability of data points from the mean.
# Term:Statistical Significance, Value:A measure of how likely an observed effect or result is not due to chance, often expressed as a p-value.
# Term:Time Series Analysis, Value:Analyzing data collected over time to identify patterns, trends, and seasonality.

# %%
#Load model and tokenizer
model_name = 'bert-base-nli-mean-tokens'
model = SentenceTransformer(model_name)

#Function to encode text to vector using SentenceTransformer
def encode(text):

   return model.encode(text, convert_to_tensor=True)
# Out:
# .gitattributes:   0%|          | 0.00/391 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/399 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
random.seed(42)

random_term = random.choice(list(terms_dict.keys()))
answer = terms_dict[random_term]  # Fix the typo here
print(f"Please describe: {random_term}")
user_input = input("Your Answer: ")

# Encoding
answer_vector = encode(answer).unsqueeze(0)
user_input_vector = encode(user_input).unsqueeze(0)

# Cosine Similarity
similarity = cosine_similarity(answer_vector, user_input_vector)

print(f"Answer: {answer}")  # Fix the typo here
print(f"Cosine Similarity: {similarity[0][0]}")
# Out:
# Please describe: Overfitting
# Your Answer: Cross-Validation
# Answer: Occurs when a machine learning model learns the training data too well but performs poorly on unseen data.
# Cosine Similarity: 0.27562814950942993
